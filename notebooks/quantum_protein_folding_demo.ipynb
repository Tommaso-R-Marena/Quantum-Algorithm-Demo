# %% [markdown]
# # Quantum Protein Folding Framework (QPF) Demo
#
# This notebook demonstrates the capabilities of the Quantum Protein Folding Framework, which uses Quantum Fragment Assembly (QFA) and hybrid quantum-classical optimization to predict protein structures.

# %%
# Install dependencies
# !pip install pennylane matplotlib numpy scipy plotly pytest

# %%
# Clone the repository
# !git clone https://github.com/user/Quantum-Algorithm-Demo.git
# %cd Quantum-Algorithm-Demo

# %%
# Set PYTHONPATH to include the src directory
import os
import sys
sys.path.append(os.path.abspath('src'))

# %% [markdown]
# ## Run a Real Protein Prediction (Chignolin)
#
# We will use Simulated Annealing as the classical solver for this demo. The framework also supports VQE and QAOA.

# %%
# !python -m quantum_fold.main --mode real --benchmark chignolin --method sa --outdir demo_results

# %% [markdown]
# ## Visualize Results
#
# The framework generates interactive 3D visualizations using Plotly.

# %%
import IPython
IPython.display.HTML(filename='demo_results/sa_YYDPETGTWY_interactive.html')
